# %% [markdown]
# <a href="https://colab.research.google.com/github/VikasAdhikari07/LLM-News-Classifier/blob/main/LLM%20Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Preparing Dataset
df = pd.read_csv('clustering.xlsx - sheet1.csv')
df['Category'] = None

# %%
df = df[['Text','Category']].head(10)

# %%
import requests
TOKEN = "" # Write your token here
API_URL = "https://api-inference.huggingface.co/models/facebook/bart-large-mnli"
headers = {"Authorization": f"Bearer {TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

categories = [
    "Politics and Governance",
    "Business and Economy",
    "Technology and Science",
    "Sports and Entertainment",
    "Health and Lifestyle",
    "World News and Social Issues"
]

# %%
for i in range(df.shape[0]):
  output = query({
    "inputs": df.loc[i,"Text"],
    "parameters": {"candidate_labels": categories},
    })
  # Check if the API call was successful by checking for the 'labels' key
  if 'labels' in output:
    category = output['labels'][0]
    df.loc[i,'Category'] = category

# %%
df
# Out:
#                                                 Text                  Category
# 0  Moeller's student-run newspaper, The Crusader,...   Politics and Governance
# 1  In 2008, The Crusader won First Place, the sec...      Business and Economy
# 2  The Squire is a student literary journal that ...   Politics and Governance
# 3  Paul Keels - play-by-play announcer for Ohio S...  Sports and Entertainment
# 4           Joe Uecker - Ohio State Senator (R-66) .   Politics and Governance
# 5  Rico Murray - Undrafted free agent signee by t...      Health and Lifestyle
# 6  Tony Hunter - professional football player for...  Sports and Entertainment
# 7  Jack Norris - President and co-founder of Vega...      Health and Lifestyle
# 8  Archbishop Moeller High School was established...   Politics and Governance
# 9  Moeller High School opened its doors in Septem...   Politics and Governance

# %%
df.to_csv('output.csv')
